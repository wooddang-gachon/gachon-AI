# %%
# 구글 드라이브 연결 
from google.colab import drive
drive.mount('/content/drive')
folder_dir = "/content/drive/MyDrive/Colab Notebooks/"
DATA_FILE = "breast_cancer.csv"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 마운트 및 csv파일 출력

import pandas as pd
import os

# 디렉토리 경로와 파일명을 결합하여 파일 시스템 내 절대 경로를 확정
file_path = os.path.join(folder_dir, DATA_FILE)

# CSV 데이터 파싱 및 메모리 내 DataFrame 객체 생성
try:
    df = pd.read_csv(file_path)
    
    # Colab 인터랙티브 환경의 데이터 렌더링 기능을 활용한 출력
    display(df)
except FileNotFoundError:
    print(f"오류: 지정된 경로에서 파일을 식별할 수 없습니다. ({file_path})")
# Out:
#      Unnamed: 0  mean radius  mean texture  mean perimeter  mean area  \
# 0             0        17.99         10.38          122.80     1001.0
# 1             1        20.57         17.77          132.90     1326.0
# 2             2        19.69         21.25          130.00     1203.0
# 3             3        11.42         20.38           77.58      386.1
# 4             4        20.29         14.34          135.10     1297.0
# ..          ...          ...           ...             ...        ...
# 564         564        21.56         22.39          142.00     1479.0
# 565         565        20.13         28.25          131.20     1261.0
# 566         566        16.60         28.08          108.30      858.1
# 567         567        20.60         29.33          140.10     1265.0
# 568         568         7.76         24.54           47.92      181.0
#
#      mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      mean symmetry  ...  worst texture  worst perimeter  worst area  \
# 0           0.2419  ...          17.33           184.60      2019.0
# 1           0.1812  ...          23.41           158.80      1956.0
# 2           0.2069  ...          25.53           152.50      1709.0
# 3           0.2597  ...          26.50            98.87       567.7
# 4           0.1809  ...          16.67           152.20      1575.0
# ..             ...  ...            ...              ...         ...
# 564         0.1726  ...          26.40           166.10      2027.0
# 565         0.1752  ...          38.25           155.00      1731.0
# 566         0.1590  ...          34.12           126.70      1124.0
# 567         0.2397  ...          39.42           184.60      1821.0
# 568         0.1587  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  label
# 0                  0.2654          0.4601                  0.11890      0
# 1                  0.1860          0.2750                  0.08902      0
# 2                  0.2430          0.3613                  0.08758      0
# 3                  0.2575          0.6638                  0.17300      0
# 4                  0.1625          0.2364                  0.07678      0
# ..                    ...             ...                      ...    ...
# 564                0.2216          0.2060                  0.07115      0
# 565                0.1628          0.2572                  0.06637      0
# 566                0.1418          0.2218                  0.07820      0
# 567                0.2650          0.4087                  0.12400      0
# 568                0.0000          0.2871                  0.07039      1
#
# [569 rows x 32 columns]

# %%
# 테스트셋, 학습셋 형성
X = df.drop('label',axis = 1)
X = X.drop('worst compactness',axis = 1)
display(X)

Y=df['worst compactness']
display(Y)

## 테스트 집단 추출

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y,test_size=0.25,random_state=0)
# Out:
#      Unnamed: 0  mean radius  mean texture  mean perimeter  mean area  \
# 0             0        17.99         10.38          122.80     1001.0
# 1             1        20.57         17.77          132.90     1326.0
# 2             2        19.69         21.25          130.00     1203.0
# 3             3        11.42         20.38           77.58      386.1
# 4             4        20.29         14.34          135.10     1297.0
# ..          ...          ...           ...             ...        ...
# 564         564        21.56         22.39          142.00     1479.0
# 565         565        20.13         28.25          131.20     1261.0
# 566         566        16.60         28.08          108.30      858.1
# 567         567        20.60         29.33          140.10     1265.0
# 568         568         7.76         24.54           47.92      181.0
#
#      mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      mean symmetry  ...  fractal dimension error  worst radius  worst texture  \
# 0           0.2419  ...                 0.006193        25.380          17.33
# 1           0.1812  ...                 0.003532        24.990          23.41
# 2           0.2069  ...                 0.004571        23.570          25.53
# 3           0.2597  ...                 0.009208        14.910          26.50
# 4           0.1809  ...                 0.005115        22.540          16.67
# ..             ...  ...                      ...           ...            ...
# 564         0.1726  ...                 0.004239        25.450          26.40
# 565         0.1752  ...                 0.002498        23.690          38.25
# 566         0.1590  ...                 0.003892        18.980          34.12
# 567         0.2397  ...                 0.006185        25.740          39.42
# 568         0.1587  ...                 0.002783         9.456          30.37
#
#      worst perimeter  worst area  worst smoothness  worst concavity  \
# 0             184.60      2019.0           0.16220           0.7119
# 1             158.80      1956.0           0.12380           0.2416
# 2             152.50      1709.0           0.14440           0.4504
# 3              98.87       567.7           0.20980           0.6869
# 4             152.20      1575.0           0.13740           0.4000
# ..               ...         ...               ...              ...
# 564           166.10      2027.0           0.14100           0.4107
# 565           155.00      1731.0           0.11660           0.3215
# 566           126.70      1124.0           0.11390           0.3403
# 567           184.60      1821.0           0.16500           0.9387
# 568            59.16       268.6           0.08996           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 30 columns]
# 0      0.66560
# 1      0.18660
# 2      0.42450
# 3      0.86630
# 4      0.20500
#         ...
# 564    0.21130
# 565    0.19220
# 566    0.30940
# 567    0.86810
# 568    0.06444
# Name: worst compactness, Length: 569, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

import pandas as pd
import numpy as np

# %%
breastCancerLinearRegression = LinearRegression()
breastCancerLinearRegression.fit(X_train, Y_train)
predLinearRegression = breastCancerLinearRegression.predict(X_test)

print('평균제곱근오차', mean_squared_error(predLinearRegression, Y_test))

def mse_np(actual, predicted):
    return np.mean((np.array(actual) - np.array(predicted)) ** 2)

print('평균제곱근오차', mse_np(predLinearRegression, Y_test))

def mse(actual, predicted):
    sum_square_error = sum((a - p) ** 2 for a, p in zip(actual, predicted))
    mean_square_error = sum_square_error / len(actual)
    return mean_square_error

print('평균제곱근오차', mse(predLinearRegression, Y_test))
# Out:
# 평균제곱근오차 0.0004937274846573661
# 평균제곱근오차 0.0004937274846573661
# 평균제곱근오차 0.0004937274846573658
